# %%
import pandas as pn
import numpy as np
import math 
import random

# %%
data=pn.read_csv("linear.csv",header=None)
data
# Out:
#             0         1
# 0    0.067732  3.176513
# 1    0.427810  3.816464
# 2    0.995731  4.550095
# 3    0.738336  4.256571
# 4    0.981083  4.560815
# 5    0.526171  3.929515
# 6    0.378887  3.526170
# 7    0.033859  3.156393
# 8    0.132791  3.110301
# 9    0.138306  3.149813
# 10   0.247809  3.476346
# 11   0.648270  4.119688
# 12   0.731209  4.282233
# 13   0.236833  3.486582
# 14   0.969788  4.655492
# 15   0.607492  3.965162
# 16   0.358622  3.514900
# 17   0.147846  3.125947
# 18   0.637820  4.094115
# 19   0.230372  3.476039
# 20   0.070237  3.210610
# 21   0.067154  3.190612
# 22   0.925577  4.631504
# 23   0.717733  4.295890
# 24   0.015371  3.085028
# 25   0.335070  3.448080
# 26   0.040486  3.167440
# 27   0.212575  3.364266
# 28   0.617218  3.993482
# 29   0.541196  3.891471
# ..        ...       ...
# 170  0.218023  3.380820
# 171  0.869778  4.565020
# 172  0.196830  3.279973
# 173  0.958178  4.554241
# 174  0.972673  4.633520
# 175  0.745797  4.281037
# ...

# %%
dataArray = np.array(data)
dataArray
# Out:
# array([[0.067732, 3.176513],
#        [0.42781 , 3.816464],
#        [0.995731, 4.550095],
#        [0.738336, 4.256571],
#        [0.981083, 4.560815],
#        [0.526171, 3.929515],
#        [0.378887, 3.52617 ],
#        [0.033859, 3.156393],
#        [0.132791, 3.110301],
#        [0.138306, 3.149813],
#        [0.247809, 3.476346],
#        [0.64827 , 4.119688],
#        [0.731209, 4.282233],
#        [0.236833, 3.486582],
#        [0.969788, 4.655492],
#        [0.607492, 3.965162],
#        [0.358622, 3.5149  ],
#        [0.147846, 3.125947],
#        [0.63782 , 4.094115],
#        [0.230372, 3.476039],
#        [0.070237, 3.21061 ],
#        [0.067154, 3.190612],
#        [0.925577, 4.631504],
#        [0.717733, 4.29589 ],
#        [0.015371, 3.085028],
#        [0.33507 , 3.44808 ],
#        [0.040486, 3.16744 ],
#        [0.212575, 3.364266],
#        [0.617218, 3.993482],
#        [0.541196, 3.891471],
#        [0.045353, 3.143259],
#        [0.126762, 3.114204],
# ...

# %%
x=dataArray[:,:-1]
y=dataArray[:,1:]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def linear_regression(x,y):
    w0=0.5
    w1=0.5
    length=len(x)/2
    alpha=.001
    j=[]

    for i in range(10000):
        j.append(sum((y-(w0+w1*x)**2)))
        predict_y =(w0+(w1*x))/length
        slope_w0 =sum((y-predict_y)*(-1))
        slope_w1 =sum((y-predict_y)*(-x))
        w0=w0-(alpha*slope_w0)
        w1=w1-(alpha*slope_w1)     
        
    return predict_y,j

# %%
predict_y,j=linear_regression(x,y)

# %%
color='blue'
plt.scatter(x,y,c=color)
plt.scatter(x,predict_y,c='red',marker='.')
plt.xlabel("Population")
plt.ylabel("Profit")
# Out:
# Text(0,0.5,'Profit')

# %%
plt.plot([i for i in range(10000)],j)
plt.xlabel("iteration")
plt.ylabel("cost")
# Out:
# Text(0,0.5,'cost')
